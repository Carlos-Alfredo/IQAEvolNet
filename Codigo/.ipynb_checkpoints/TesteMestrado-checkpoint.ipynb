# %%
import torchvision
from PIL import Image
import argparse
import matplotlib.pyplot as plt
import numpy as np
import torch
from torchvision.transforms import ToPILImage
import time
import sys
import torch.multiprocessing as mp
import os

# %%
sys.path.insert(1, 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo')

# %%
mp.cpu_count()
# Out:
# 8

# %%
from inference import image_haze_removel
import metric  as  metric
import evolution as  evolution

# %%
import importlib
import evolution
importlib.reload(evolution)
importlib.reload(torch.multiprocessing)
if __name__ == '__main__':
		mp.set_start_method('spawn',force=True)

# %%
def dehaze_test(image_path,weight):
	metrics = np.asarray([0,0])
	for input in image_path:
		hazy_input_image = Image.open(input)

		dehaze_image = image_haze_removel(hazy_input_image,weight)
		# torchvision.utils.save_image(dehaze_image, "dehaze.jpg")
		tensor_image = dehaze_image  # Your tensor image
		tensor_image = tensor_image.cpu()  # Move tensor to CPU if it's on GPU
		tensor_image = tensor_image.squeeze(0)  # Remove the batch dimension if present

		# Convert the tensor to a PIL image
		to_pil = ToPILImage()
		pil_image = to_pil(tensor_image)

		metrics = metrics + np.asarray([metric.PSNR(hazy_input_image,pil_image),metric.SSIM(np.array(hazy_input_image),np.array(pil_image))])
	return metrics/len(image_path)

# %%
def list_split(original_list,number_of_splits):
    sub_list = []
    split = []
    number_of_elements = len(original_list)
    split_size = int(number_of_elements/number_of_splits)
    extra_elements = number_of_elements%number_of_splits
    last_element = 0
    for i in range(0,number_of_splits):
        if i < extra_elements:
            sub_list.append(original_list[last_element:last_element+split_size+1])
            last_element = last_element+split_size+1
        else:
            sub_list.append(original_list[last_element:last_element+split_size])
            last_element = last_element+split_size
    return sub_list
# Out:
# [['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/001.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/002.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/003.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/004.jpg'],
#  ['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/005.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/006.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/007.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/008.jpg'],
#  ['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/009.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/010.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/011.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/012.jpg'],
#  ['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/013.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/014.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/015.jpg',
#   'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/016.jpg']]

# %%
path = "C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/"

img = path+ "047.jpg"

# weight = torch.load('C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/trained_weights/trained_LDNet.pth')
weight_cpu = torch.load('C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/trained_weights/trained_LDNet.pth',map_location='cpu')

device1 = [	path+ "017.jpg",path+ "018.jpg",path+ "019.jpg",path+ "020.jpg",path+ "021.jpg",path+ "022.jpg",path+ "023.jpg",path+ "024.jpg"]
device2 = [	path+ "001.jpg", path+ "002.jpg",path+ "003.jpg",path+ "004.jpg",path+ "005.jpg",path+ "006.jpg",path+ "007.jpg",path+ "008.jpg",
			path+ "009.jpg",path+ "010.jpg",path+ "011.jpg",path+ "012.jpg",path+ "013.jpg",path+ "014.jpg",path+ "015.jpg",path+ "016.jpg"]
device3 = [	path+ "025.jpg", path+ "026.jpg",path+ "027.jpg",path+ "028.jpg",path+ "029.jpg",path+ "030.jpg"]

device = []
for file in os.listdir(path):
	device.append(path+file)

evolutionProcess = evolution.EvolutionaryProcess(weight_cpu,16,4,0.01,3,list_split(device2,4))

optimized_weight = evolutionProcess.return_apex()
# Out:
# 16

# %%
evolutionProcess.evolve(4)
# Out:
# [['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/001.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/002.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/003.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/004.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/005.jpg'], ['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/006.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/007.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/008.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/009.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/010.jpg'], ['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/011.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/012.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/013.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/014.jpg', 'C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/015.jpg'], ['C:/Users/carlo/Documents/GitHub/Mestrado/Codigo/img_teste/016.jpg']]
# -> Round  0
# 4
# There was no improvement this round!

# %%
optimized_weight = evolutionProcess.return_apex()

print("Original model: ")
# print(dehaze_test(device1+device2+device3 , weight))
print([12.85458435 , 0.55657224])

print("\nOptimized model: ")
print(dehaze_test(device1+device2+device3 , optimized_weight))
# Out:
# Original model:
# [12.85458435, 0.55657224]
#
# Optimized model:
# [13.67016329  0.64877462]

# %%
input = path+ "010.jpg"

weight = torch.load('/content/drive/MyDrive/Mestrado/Codigo/trained_weights/trained_LDNet.pth')

optimized_weight = evolutionProcess.return_apex()

def enhancementTest(input,weight):
  hazy_input_image = Image.open(input)

  dehaze_image = image_haze_removel(hazy_input_image,weight)
  # torchvision.utils.save_image(dehaze_image, "dehaze.jpg")
  tensor_image = dehaze_image  # Your tensor image
  tensor_image = tensor_image.cpu()  # Move tensor to CPU if it's on GPU
  tensor_image = tensor_image.squeeze(0)  # Remove the batch dimension if present

  # Convert the tensor to a PIL image
  to_pil = ToPILImage()
  pil_image = to_pil(tensor_image)

  pil_image.show()

enhancementTest(input,weight)
enhancementTest(input,optimized_weight)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7EFD7A945F00>
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7EFD7A946080>

# %%
import torch

device_count = torch.cuda.device_count()
print("Number of CUDA devices available:", device_count)

for i in range(device_count):
    device_name = torch.cuda.get_device_name(i)
    print("CUDA device", i, ":", device_name)
# Out:
# Number of CUDA devices available: 1
# CUDA device 0 : Tesla T4

# %%
import torch.multiprocessing as mp

mp.cpu_count()
# Out:
# 2
